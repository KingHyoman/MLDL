# %% [markdown]
# Q5.

# %%
import pandas as pd
Auto = pd.read_csv('Dataset/Auto.csv')

Auto_backup = Auto
Auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %% [markdown]
# (a)
# quantitative: mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin
# qualitative: name

# %%
Auto_column = Auto.columns

for column in Auto_column:
    if column == 'name':
        continue
    max, min = Auto[column][0], Auto[column][0]
    for i in Auto[column]:
        if i == '?':
            continue
        if float(i) > float(max):
            max = float(i)
        if float(i) < float(min):
            min = float(i)
    print(f'the range of {column} is {max - min}')
    print(f'[{max}, {min}]')
# Out:
# the range of mpg is 37.6
# [46.6, 9.0]
# the range of cylinders is 5.0
# [8, 3.0]
# the range of displacement is 387.0
# [455.0, 68.0]
# the range of horsepower is 184.0
# [230.0, 46.0]
# the range of weight is 3527.0
# [5140.0, 1613.0]
# the range of acceleration is 16.8
# [24.8, 8.0]
# the range of year is 12.0
# [82.0, 70]
# the range of origin is 2.0
# [3.0, 1]

# %% [markdown]
# (b)
# the range of mpg is 37.6
# the range of cylinders is 5.0
# the range of displacement is 387.0
# the range of horsepower is 184.0
# the range of weight is 3527.0
# the range of acceleration is 16.8
# the range of year is 12.0
# the range of origin is 2.0

# %%
import numpy
Auto_column = Auto.columns

for column in Auto_column:
    if column == 'name':
        continue
    tem = []
    for i in Auto[column]:
        if i == '?':
            continue
        tem.append(float(i))

    print(f'the mean of {column} is {numpy.mean(tem)}')
    print(f'the std of {column} is {numpy.std(tem)}')
    print()
# Out:
# the mean of mpg is 23.51586901763224
# the std of mpg is 7.815941538224256
#
# the mean of cylinders is 5.458438287153652
# the std of cylinders is 1.6994325855091355
#
# the mean of displacement is 193.53274559193954
# the std of displacement is 104.24803997948834
#
# the mean of horsepower is 104.46938775510205
# the std of horsepower is 38.44203271442593
#
# the mean of weight is 2970.2619647355164
# the std of weight is 846.8355568478047
#
# the mean of acceleration is 15.55566750629723
# the std of acceleration is 2.746529639056109
#
# the mean of year is 75.99496221662469
# the std of year is 3.6853546098832237
#
# the mean of origin is 1.5743073047858942
# the std of origin is 0.801538090863641

# %% [markdown]
# (c)
# the mean of mpg is 23.51586901763224
# the std of mpg is 7.815941538224256
#
# the mean of cylinders is 5.458438287153652
# the std of cylinders is 1.6994325855091355
#
# the mean of displacement is 193.53274559193954
# the std of displacement is 104.24803997948834
#
# the mean of horsepower is 104.46938775510205
# the std of horsepower is 38.44203271442593
#
# the mean of weight is 2970.2619647355164
# the std of weight is 846.8355568478047
#
# the mean of acceleration is 15.55566750629723
# the std of acceleration is 2.746529639056109
#
# the mean of year is 75.99496221662469
# the std of year is 3.6853546098832237
#
# the mean of origin is 1.5743073047858942
# the std of origin is 0.801538090863641

# %%
Auto_new = Auto.drop([i for i in range(9, 85)])
Auto = Auto_new

# %%
Auto_column = Auto.columns

for column in Auto_column:
    if column == 'name':
        continue
    max, min = Auto[column][0], Auto[column][0]
    for i in Auto[column]:
        if i == '?':
            continue
        if float(i) > float(max):
            max = float(i)
        if float(i) < float(min):
            min = float(i)
    print(f'the range of {column} is {max - min}')
# Out:
# the range of mpg is 35.6
# the range of cylinders is 5.0
# the range of displacement is 387.0
# the range of horsepower is 184.0
# the range of weight is 3348.0
# the range of acceleration is 16.3
# the range of year is 12.0
# the range of origin is 2.0

# %%
import numpy
Auto_column = Auto.columns

for column in Auto_column:
    if column == 'name':
        continue
    tem = []
    for i in Auto[column]:
        if i == '?':
            continue
        tem.append(float(i))

    print(f'the mean of {column} is {numpy.mean(tem)}')
    print(f'the std of {column} is {numpy.std(tem)}')
    print()
# Out:
# the mean of mpg is 24.438629283489096
# the std of mpg is 7.895856596479212
#
# the mean of cylinders is 5.370716510903427
# the std of cylinders is 1.650908119022148
#
# the mean of displacement is 187.04984423676012
# the std of displacement is 99.48006895812564
#
# the mean of horsepower is 100.95583596214512
# the std of horsepower is 35.83890444223678
#
# the mean of weight is 2933.96261682243
# the std of weight is 809.3792697745698
#
# the mean of acceleration is 15.723052959501558
# the std of acceleration is 2.676335319376774
#
# the mean of year is 77.15264797507788
# the std of year is 3.106379853135528
#
# the mean of origin is 1.5981308411214954
# the std of origin is 0.814890391698078

# %% [markdown]
# (d)
# the range of mpg is 35.6
# the range of cylinders is 5.0
# the range of displacement is 387.0
# the range of horsepower is 184.0
# the range of weight is 3348.0
# the range of acceleration is 16.3
# the range of year is 12.0
# the range of origin is 2.0
#
# the mean of mpg is 24.438629283489096
# the std of mpg is 7.895856596479212
#
# the mean of cylinders is 5.370716510903427
# the std of cylinders is 1.650908119022148
#
# the mean of displacement is 187.04984423676012
# the std of displacement is 99.48006895812564
#
# the mean of horsepower is 100.95583596214512
# the std of horsepower is 35.83890444223678
#
# the mean of weight is 2933.96261682243
# the std of weight is 809.3792697745698
#
# the mean of acceleration is 15.723052959501558
# the std of acceleration is 2.676335319376774
#
# the mean of year is 77.15264797507788
# the std of year is 3.106379853135528
#
# the mean of origin is 1.5981308411214954
# the std of origin is 0.814890391698078

# %% [markdown]
# (e) Refer to below figures.

# %%
import matplotlib.pyplot as plt

Auto = Auto_backup
#Auto

arr = []

for column in Auto_column:
    if column == 'name':
        continue
    tem = (column, [])
    for i in Auto[column]:
        if i == '?':
            i = 0
        tem[1].append(float(i))
    arr.append(tem)

for i in range(len(arr)):
    for j in range(len(arr)):
        x = arr[i][1]
        y = arr[j][1]

        if len(x) != len(y):
            continue
        plt.scatter(x, y)
        plt.xlabel(arr[i][0])
        plt.ylabel(arr[j][0])
        plt.show()

# %% [markdown]
# 1. There are some linear relationship: displacement - weight, horespower - weight.
# 2. Origin, year and cylinders have constant relationship with the others.

# %%
for i in range(len(arr)):
    for j in range(len(arr)):
        x = arr[i][1]
        y = arr[j][1]

        if len(x) != len(y):
            continue
        if arr[j][0] == 'mpg':
            plt.scatter(x, y)
            plt.xlabel(arr[i][0])
            plt.ylabel(arr[j][0])
            plt.show()

# %% [markdown]
# (f)
# Following above figures, we can find useful relationships weight, horsepower and displacement to mpg. Thus they can be used as predictors.
